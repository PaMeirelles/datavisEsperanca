# %%
import pickle
import pprint

# %%
with open("data/by_number/51.pkl", "rb") as f:
    data = pickle.load(f)

# %%
pprint.pprint(data)

# %%
import networkx as nx

with open("data/by_number/51.pkl", "rb") as f:
    G = pickle.load(f)

print(type(G))                  # Should confirm <class 'networkx.classes.graph.Graph'>
print(G.nodes(data=True))       # List of by_number with attributes
print(G.edges(data=True))       # List of edges with attributes
print(G.number_of_nodes())      # Number of by_number
print(G.number_of_edges())      # Number of edges
# Out:
# <class 'networkx.classes.graph.Graph'>
# ...

# %%
with open("data/by_number/52.pkl", "rb") as f:
    G = pickle.load(f)

print(type(G))                  # Should confirm <class 'networkx.classes.graph.Graph'>
print(G.nodes(data=True))       # List of by_number with attributes
print(G.edges(data=True))       # List of edges with attributes
print(G.number_of_nodes())      # Number of by_number
print(G.number_of_edges())      # Number of edges
# Out:
# <class 'networkx.classes.graph.Graph'>
# ...

# %%
with open("data/by_year/1999.pkl", "rb") as f:
    G = pickle.load(f)

print(type(G))                  # Should confirm <class 'networkx.classes.graph.Graph'>
print(G.nodes(data=True))       # List of by_number with attributes
print(G.edges(data=True))       # List of edges with attributes
print(G.number_of_nodes())      # Number of by_number
print(G.number_of_edges())      # Number of edges
# Out:
# <class 'networkx.classes.graph.Graph'>
# ...
